# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dataset = df.values
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.2, random_state=0)
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5, random_state=0)

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras import regularizers
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Construcción del Modelo

# %%
model = Sequential([
    Dense(30, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(8,)),
    Dropout(0.3),
    Dense(50, activation='linear', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(50, activation='linear', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(16, activation='linear', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
hist = model.fit(X_train, Y_train,batch_size=32, epochs=1000,validation_data=(X_val, Y_val))
# Out:
# Train on 614 samples, validate on 77 samples
# Epoch 1/1000
# 614/614 [==============================] - 1s 1ms/step - loss: 1.9232 - accuracy: 0.5863 - val_loss: 1.7804 - val_accuracy: 0.6883
# Epoch 2/1000
# 614/614 [==============================] - 0s 155us/step - loss: 1.7426 - accuracy: 0.6254 - val_loss: 1.6358 - val_accuracy: 0.6883
# Epoch 3/1000
# 614/614 [==============================] - 0s 136us/step - loss: 1.5900 - accuracy: 0.6498 - val_loss: 1.4988 - val_accuracy: 0.6883
# Epoch 4/1000
# 614/614 [==============================] - 0s 163us/step - loss: 1.4734 - accuracy: 0.6433 - val_loss: 1.3844 - val_accuracy: 0.6883
# Epoch 5/1000
# 614/614 [==============================] - 0s 130us/step - loss: 1.3624 - accuracy: 0.6401 - val_loss: 1.2835 - val_accuracy: 0.6883
# Epoch 6/1000
# 614/614 [==============================] - 0s 145us/step - loss: 1.2732 - accuracy: 0.6433 - val_loss: 1.1952 - val_accuracy: 0.6883
# Epoch 7/1000
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(hist.history['loss'],color='#2980b9')
plt.plot(hist.history['val_loss'],color='#7f8c8d')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(top=1.0, bottom=0.0)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(hist.history['accuracy'],color='#2980b9')
plt.plot(hist.history['val_accuracy'],color='#7f8c8d')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 77/77 [==============================] - 0s 283us/step
# 0.8441558480262756

# %%
pred = model.predict(X_test)
Y_pred = (pred > 0.5)
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[50,  4],
#        [ 8, 15]])

# %% [markdown]
# # Save a model

# %%
model.save("model-8-30-50-50-16-1.h5")

# %% [markdown]
# # Load a model

# %%
model = load_model('model-8-30-50-50-16-1.h5')

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 77/77 [==============================] - 0s 1ms/step
# 0.8441558480262756

# %%
model2 = Sequential([
    Dense(16, activation='relu',input_shape=(8,)),
    Dense(4, activation='linear'),
    Dense(16, activation='linear'),
    Dense(1, activation='sigmoid'),
])
model2.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
hist2 = model2.fit(X_train, Y_train,batch_size=32, epochs=1000,validation_data=(X_val, Y_val))
# Out:
# Train on 614 samples, validate on 77 samples
# Epoch 1/1000
# 614/614 [==============================] - 0s 511us/step - loss: 0.7087 - accuracy: 0.4202 - val_loss: 0.6753 - val_accuracy: 0.7273
# Epoch 2/1000
# 614/614 [==============================] - 0s 77us/step - loss: 0.6720 - accuracy: 0.6450 - val_loss: 0.6442 - val_accuracy: 0.6883
# Epoch 3/1000
# 614/614 [==============================] - 0s 78us/step - loss: 0.6578 - accuracy: 0.6401 - val_loss: 0.6337 - val_accuracy: 0.6883
# Epoch 4/1000
# 614/614 [==============================] - 0s 78us/step - loss: 0.6517 - accuracy: 0.6401 - val_loss: 0.6260 - val_accuracy: 0.6883
# Epoch 5/1000
# 614/614 [==============================] - 0s 81us/step - loss: 0.6459 - accuracy: 0.6401 - val_loss: 0.6182 - val_accuracy: 0.6883
# Epoch 6/1000
# 614/614 [==============================] - 0s 80us/step - loss: 0.6386 - accuracy: 0.6401 - val_loss: 0.6116 - val_accuracy: 0.6883
# Epoch 7/1000
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(hist2.history['accuracy'],color='#2980b9')
plt.plot(hist2.history['val_accuracy'],color='#7f8c8d')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
model2.evaluate(X_test, Y_test)[1]
# Out:
# 77/77 [==============================] - 0s 83us/step
# 0.7922077775001526
